# %% [markdown]
# <a href="https://colab.research.google.com/github/darshannayak21/DWDM/blob/main/DWDM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone "https://github.com/darshannayak21/DWDM.git"
# Out:
# Cloning into 'DWDM'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
import pandas as pd
df= "/content/DWDM/foodResponses) - Form responses 1.csv"
print("\n Original Dataset:- \n")
df= pd.read_csv(df)
df.head()

#print("\n New Dataset:- \n")
#new_df=df.dropna()
#new_df.head()

df.fillna(545)
df.head()
# Out:
#  Original Dataset:-
#              Timestamp  \
# 0  17/01/2025 14:46:33
# 1  17/01/2025 14:46:59
# 2  17/01/2025 14:47:23
# 3  17/01/2025 14:48:22
# 4  17/01/2025 14:48:38
#
#   What type of cuisine do you prefer? (Multiple Choice)    \
# 0                             Other (please specify)
# 1                                             Indian
# 2                                      Mediterranean
# 3                                            Chinese
# 4                                            Mexican
#
#   How often do you eat out? (Multiple Choice)    \
# 0                                   Once a week
# 1                              2-3 times a week
# 2                                   Once a week
# 3                              2-3 times a week
# 4                                        Rarely
#
#   What’s your favorite meal of the day? (Multiple Choice)    \
# 0                                             Dinner
# 1                                              Lunch
# ...
